# %%
from train_network import Trainer
import matplotlib.pyplot as plt


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_session = Trainer(**{'runtime': 5, 'load_net': False})

# %%
# %matplotlib inline
plt.style.use({'figure.facecolor': 'white'})
train_session.train()
# Out:
#  18%|█▊        | 53/300 [11:54<55:30, 13.48s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10148/48547671.py in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 plt.style.use({'figure.facecolor': 'white'})
# ----> 3 train_session.train()
#       4
#
# ~\Documents\GitHub\ML project\ML_2021_quantum_control\train_network.py in train(self)
#      76                         action, action_p = self.net.sample_action(state, prev_state)
#      77
# ---> 78                     new_state, reward, done, info = self.env.step(action)
#      79                     self.memory_bank.add_event(state, prev_state, action, action_p, reward)
#      80
#
# ~\Documents\GitHub\ML project\ML_2021_quantum_control\simulation.py in step(self, action)
#     107         ham_tot = hx * sigmax() + hy * sigmay() + hz * sigmaz()
#     108
# ...

# %%
# %matplotlib qt
train_session.probe_learning()
