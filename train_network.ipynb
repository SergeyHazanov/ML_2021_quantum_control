# %%
from train_network import Trainer
import matplotlib.pyplot as plt
import sys

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_session = Trainer(**{'n_epochs': 300,
                           'batch_size': 10000,
                           'runtime': 4,
                           'load_net': False,
                           'net_name': 'experiment_net.pt'})

# %%
# %matplotlib inline
plt.style.use({'figure.facecolor': 'white'})
train_session.train()
# Out:
#  12%|█▏        | 36/300 [06:54<52:14, 11.87s/it]

# %%
# %matplotlib qt
train_session.probe_learning()

# %%
# sys.path.insert(0, r':\CProgram Files\ffmpeg-2021-08-08-git-ac0408522a-full_build\bin')
# %matplotlib qt
plt.rcParams['animation.ffmpeg_path'] = r'C:/Users/rosengrp/Documents/GitHub\ML project\ML_2021_quantum_control/ffmpeg'
anim = train_session.game_animation(fig_size=(12, 12), save=False, fps=60)
