# %%
from train_network import Trainer
import matplotlib.pyplot as plt
import sys

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_session = Trainer(**{'n_epochs': 100,
                           'batch_size': 30000,
                           'games_per_epoch': 20,
                           'runtime': 2,
                           'load_net': False,
                           'net_name': 'experiment_net.pt',
                           'decay_rate': 0.96})

# %%
# %matplotlib inline

plt.style.use({'figure.facecolor': 'white'})
train_session.train()
# Out:
# 100%|██████████| 100/100 [20:35<00:00, 12.35s/it]

# %%
# %matplotlib qt

train_session.probe_learning()
# Out:
# (2, 0.1712358593940735)
# 0.0
# (5, 0.2154327630996704)
# 0.01
# (5, 0.21602723002433777)
# 0.02
# (5, 0.21662341058254242)
# 0.03
# (2, 0.17155656218528748)
# 0.04
# (2, 0.17155149579048157)
# 0.05
# (5, 0.21858984231948853)
# 0.060000000000000005
# (5, 0.21916155517101288)
# 0.07
# (8, 0.34752315282821655)
# 0.08
# (5, 0.2201886922121048)
# 0.09
# (2, 0.17172013223171234)
# 0.09999999999999999
# (5, 0.22141499817371368)
# 0.10999999999999999
# (5, 0.22197549045085907)
# 0.11999999999999998
# (8, 0.36235368251800537)
# 0.12999999999999998
# (1, 0.04257390648126602)
# 0.13999999999999999
# (2, 0.17146338522434235)
# 0.13999999999999999
# (7, 0.03132212534546852)
# 0.15
# (7, 0.03132343664765358)
# 0.15
# (3, 0.06875556707382202)
# 0.15
# (2, 0.17154653370380402)
# 0.13999999999999999
# (8, 0.3718187212944031)
# 0.15
# (1, 0.04055202752351761)
# 0.16
# (3, 0.06751873344182968)
# 0.16
# (8, 0.3737892508506775)
# 0.15
# (8, 0.3764466345310211)
# 0.16
# (8, 0.37910696864128113)
# 0.17
# (5, 0.22581177949905396)
# 0.18000000000000002
# (5, 0.22629034519195557)
# 0.19000000000000003
# (8, 0.38877373933792114)
# 0.20000000000000004
# (8, 0.39157527685165405)
# 0.21000000000000005
# (7, 0.02690054476261139)
# 0.22000000000000006
# (8, 0.39445197582244873)
# 0.22000000000000006
# (2, 0.1709796041250229)
# 0.23000000000000007
# (3, 0.061893757432699203)
# 0.24000000000000007
# (5, 0.22818532586097717)
# 0.23000000000000007
# (3, 0.061489637941122055)
# 0.24000000000000007
# (8, 0.4016938805580139)
# 0.23000000000000007
# (8, 0.4044879376888275)
# 0.24000000000000007
# (3, 0.06058598309755325)
# 0.25000000000000006
# (8, 0.40568816661834717)
# 0.24000000000000005
# (5, 0.22918564081192017)
# 0.25000000000000006
# (8, 0.41212180256843567)
# 0.26000000000000006
# (5, 0.22981616854667664)
# 0.2700000000000001
# (2, 0.16965964436531067)
# 0.2800000000000001
# (5, 0.23047301173210144)
# 0.2900000000000001
# (8, 0.4272124171257019)
# 0.3000000000000001
# (8, 0.4302503764629364)
# 0.3100000000000001
# (8, 0.43324896693229675)
# 0.3200000000000001
# (5, 0.23140159249305725)
# 0.3300000000000001
# (5, 0.23158857226371765)
# 0.34000000000000014
# (1, 0.027187135070562363)
# 0.35000000000000014
# (5, 0.2318064123392105)
# 0.35000000000000014
# (8, 0.44993653893470764)
# 0.36000000000000015
# (1, 0.02570747770369053)
# 0.37000000000000016
# (5, 0.2320658415555954)
# 0.37000000000000016
# (5, 0.23212705552577972)
# 0.38000000000000017
# (8, 0.46280187368392944)
# 0.3900000000000002
# (8, 0.46580642461776733)
# 0.4000000000000002
# (8, 0.4688224494457245)
# 0.4100000000000002
# (8, 0.47188711166381836)
# 0.4200000000000002
# (5, 0.23229041695594788)
# 0.4300000000000002
# (8, 0.4789412319660187)
# 0.4400000000000002
# (5, 0.2322300374507904)
# 0.45000000000000023
# (8, 0.4859378933906555)
# 0.46000000000000024
# (3, 0.04291330650448799)
# 0.47000000000000025
# (8, 0.48820558190345764)
# 0.46000000000000024
# (2, 0.16090211272239685)
# 0.47000000000000025
# (8, 0.49563631415367126)
# 0.48000000000000026
# (5, 0.2317289561033249)
# 0.49000000000000027
# (8, 0.5016881823539734)
# 0.5000000000000002
# (8, 0.5041317939758301)
# 0.5100000000000002
# (2, 0.1586391180753708)
# 0.5200000000000002
# (8, 0.5109773874282837)
# 0.5300000000000002
# (2, 0.15736761689186096)
# 0.5400000000000003
# (2, 0.15625275671482086)
# 0.5500000000000003
# (8, 0.5220229625701904)
# 0.5600000000000003
# (8, 0.5242748856544495)
# 0.5700000000000003
# (5, 0.22962893545627594)
# 0.5800000000000003
# (8, 0.5295571684837341)
# 0.5900000000000003
# (8, 0.5315111875534058)
# 0.6000000000000003
# (8, 0.5333218574523926)
# 0.6100000000000003
# (8, 0.5348032712936401)
# 0.6200000000000003
# (8, 0.5361640453338623)
# 0.6300000000000003
# (8, 0.5373542308807373)
# 0.6400000000000003
# (8, 0.538362443447113)
# 0.6500000000000004
# (8, 0.5390450954437256)
# 0.6600000000000004
# (8, 0.5392674207687378)
# 0.6700000000000004
# (8, 0.5393157601356506)
# 0.6800000000000004
# (8, 0.5391199588775635)
# 0.6900000000000004
# (5, 0.22852888703346252)
# 0.7000000000000004
# (8, 0.5397992134094238)
# 0.7100000000000004
# (8, 0.5391489267349243)
# 0.7200000000000004
# (8, 0.5383073687553406)
# 0.7300000000000004
# (2, 0.16346029937267303)
# 0.7400000000000004
# (5, 0.2285495549440384)
# 0.7500000000000004
# (5, 0.22857846319675446)
# 0.7600000000000005
# (8, 0.5393766760826111)
# 0.7700000000000005
# (8, 0.5376694798469543)
# 0.7800000000000005
# (8, 0.5357880592346191)
# 0.7900000000000005
# (2, 0.17164145410060883)
# 0.8000000000000005
# (0, 0.008273031562566757)
# 0.8100000000000005
# (2, 0.1729150116443634)
# 0.8000000000000005
# (8, 0.5340836048126221)
# 0.8100000000000005
# (8, 0.5307773351669312)
# 0.8200000000000005
# (8, 0.5272692441940308)
# 0.8300000000000005
# (2, 0.1852695196866989)
# 0.8400000000000005
# (5, 0.22933386266231537)
# 0.8500000000000005
# (5, 0.22933454811573029)
# 0.8600000000000005
# (8, 0.5176438689231873)
# 0.8700000000000006
# (2, 0.19768153131008148)
# 0.8800000000000006
# (2, 0.19972170889377594)
# 0.8900000000000006
# (2, 0.2018900215625763)
# 0.9000000000000006
# (8, 0.5083990097045898)
# 0.9100000000000006
# (8, 0.5027188658714294)
# 0.9200000000000006
# (8, 0.4968944489955902)
# 0.9300000000000006
# (8, 0.49091050028800964)
# 0.9400000000000006
# (8, 0.48478060960769653)
# 0.9500000000000006
# (2, 0.233871728181839)
# 0.9600000000000006
# (2, 0.23713237047195435)
# 0.9700000000000006
# (8, 0.4719823896884918)
# 0.9800000000000006
# (8, 0.4643242359161377)
# 0.9900000000000007
# (8, 0.4563097655773163)
# 1.0000000000000007
# (5, 0.22774533927440643)
# 1.0100000000000007
# (8, 0.44132333993911743)
# 1.0200000000000007
# (2, 0.28132009506225586)
# 1.0300000000000007
# (8, 0.4265148639678955)
# 1.0400000000000007
# (8, 0.41628867387771606)
# 1.0500000000000007
# (8, 0.40445584058761597)
# 1.0600000000000007
# (2, 0.322611540555954)
# 1.0700000000000007
# (5, 0.22377559542655945)
# 1.0800000000000007
# (8, 0.3725306987762451)
# 1.0900000000000007
# (2, 0.36158475279808044)
# 1.1000000000000008
# (5, 0.2190554291009903)
# 1.1100000000000008
# (8, 0.32926231622695923)
# 1.1200000000000008
# (2, 0.41550832986831665)
# 1.1300000000000008
# (2, 0.4321603775024414)
# 1.1400000000000008
# (5, 0.20413777232170105)
# 1.1500000000000008
# (5, 0.198686420917511)
# 1.1600000000000008
# (2, 0.49889278411865234)
# 1.1700000000000008
# (5, 0.18779544532299042)
# 1.1800000000000008
# (2, 0.5418767333030701)
# 1.1900000000000008
# (2, 0.5594363212585449)
# 1.2000000000000008
# (8, 0.18752482533454895)
# 1.2100000000000009
# (8, 0.1684083640575409)
# 1.2200000000000009
# (2, 0.6347301006317139)
# 1.2300000000000009
# (2, 0.6514220237731934)
# 1.2400000000000009
# (2, 0.667856752872467)
# 1.2500000000000009
# (8, 0.11988750845193863)
# 1.260000000000001
# (2, 0.7105874419212341)
# 1.270000000000001
# (2, 0.7260614633560181)
# 1.280000000000001
# (8, 0.08855517208576202)
# 1.290000000000001
# (2, 0.7639440894126892)
# 1.300000000000001
# (2, 0.7760383486747742)
# 1.310000000000001
# (2, 0.7871960401535034)
# 1.320000000000001
# (2, 0.7979116439819336)
# 1.330000000000001
# (8, 0.05472470447421074)
# 1.340000000000001
# (5, 0.0737285315990448)
# 1.350000000000001
# (2, 0.8341395854949951)
# 1.360000000000001
# (2, 0.8404935598373413)
# 1.370000000000001
# (2, 0.8464329838752747)
# 1.380000000000001
# (2, 0.851714551448822)
# 1.390000000000001
# (2, 0.8565818667411804)
# 1.400000000000001
# (2, 0.8607895970344543)
# 1.410000000000001
# (2, 0.8642423152923584)
# 1.420000000000001
# (2, 0.8672055602073669)
# 1.430000000000001
# (2, 0.8696022629737854)
# 1.440000000000001
# (2, 0.8713334798812866)
# 1.450000000000001
# (2, 0.872527003288269)
# 1.460000000000001
# (2, 0.873140275478363)
# 1.470000000000001
# (2, 0.8732163906097412)
# 1.480000000000001
# (2, 0.8726937174797058)
# 1.490000000000001
# (2, 0.8716209530830383)
# 1.500000000000001
# (2, 0.8696945905685425)
# 1.5100000000000011
# (2, 0.8665592670440674)
# 1.5200000000000011
# (2, 0.8622664213180542)
# 1.5300000000000011
# (2, 0.8570873737335205)
# 1.5400000000000011
# (2, 0.8512802720069885)
# 1.5500000000000012
# (2, 0.8447644114494324)
# 1.5600000000000012
# (2, 0.8369474411010742)
# 1.5700000000000012
# (2, 0.8280161619186401)
# 1.5800000000000012
# (2, 0.8178238868713379)
# 1.5900000000000012
# (2, 0.8066432476043701)
# 1.6000000000000012
# (2, 0.7941487431526184)
# 1.6100000000000012
# (2, 0.7812427878379822)
# 1.6200000000000012
# (2, 0.7690780162811279)
# 1.6300000000000012
# (8, 0.04571588337421417)
# 1.6400000000000012
# (2, 0.7469936609268188)
# 1.6500000000000012
# (3, 0.05713052675127983)
# 1.6600000000000013
# (2, 0.7144099473953247)
# 1.6500000000000012
# (8, 0.05883663520216942)
# 1.6600000000000013
# (7, 0.0190547164529562)
# 1.6700000000000013
# (3, 0.07156679034233093)
# 1.6700000000000013
# (2, 0.6507475972175598)
# 1.6600000000000013
# (5, 0.09917092323303223)
# 1.6700000000000013
# (2, 0.6177206039428711)
# 1.6800000000000013
# (7, 0.024161770939826965)
# 1.6900000000000013
# (2, 0.5813583731651306)
# 1.6900000000000013
# (5, 0.11443658173084259)
# 1.7000000000000013
# (5, 0.1183936670422554)
# 1.7100000000000013
# (2, 0.5238759517669678)
# 1.7200000000000013
# Final fidelity is: 0.9872736536242476
# P_g = 0.02529073285942938

# %%
# %matplotlib qt

plt.rcParams['animation.ffmpeg_path'] = r'C:/Users/rosengrp/Documents/GitHub\ML project\ML_2021_quantum_control/ffmpeg'
# anim = train_session.game_animation(fig_size=(12, 12), save=False, fps=60)
train_session.create_gif(fname='pi_pulse.mp4')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14700/1003249001.py in <module>
#       3 plt.rcParams['animation.ffmpeg_path'] = r'C:/Users/rosengrp/Documents/GitHub\ML project\ML_2021_quantum_control/ffmpeg'
#       4 # anim = train_session.game_animation(fig_size=(12, 12), save=False, fps=60)
# ----> 5 train_session.create_gif(fname='pi_pulse.mp4')
#       6
#
# ~\Documents\GitHub\ML project\ML_2021_quantum_control\train_network.py in create_gif(self, fname)
#     273
#     274             # Saving the current picture
# --> 275             b.save(temp_fname)
#     276
#     277             # Loading the binaries from the picture
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\qutip\bloch.py in save(self, name, format, dirc, dpin)
#     687
#     688         """
# --> 689         self.render(self.fig, self.axes)
#     690         # Conditional variable for first argument to savefig
#     691         # that is set in subsequent if-elses
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\qutip\bloch.py in render(self, fig, axes)
#     486         self.plot_vectors()
#     487         self.plot_front()
# --> 488         self.plot_axes_labels()
#     489         self.plot_annotations()
#     490
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\qutip\bloch.py in plot_axes_labels(self)
#     559                   self.axes.w_xaxis.get_ticklabels()):
#     560             a.set_visible(False)
# --> 561         for a in (self.axes.w_yaxis.get_ticklines() +
#     562                   self.axes.w_yaxis.get_ticklabels()):
#     563             a.set_visible(False)
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\axis.py in get_ticklines(self, minor)
#    1249         if minor:
#    1250             return self.get_minorticklines()
# -> 1251         return self.get_majorticklines()
#    1252
#    1253     def get_majorticklocs(self):
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\axis.py in get_majorticklines(self)
#    1230         r"""Return this Axis' major tick lines as a list of `.Line2D`\s."""
#    1231         lines = []
# -> 1232         ticks = self.get_major_ticks()
#    1233         for tick in ticks:
#    1234             lines.append(tick.tick1line)
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\mpl_toolkits\mplot3d\axis3d.py in get_major_ticks(self, numticks)
#     135
#     136     def get_major_ticks(self, numticks=None):
# --> 137         ticks = super().get_major_ticks(numticks)
#     138         for t in ticks:
#     139             for obj in [
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1352         while len(self.majorTicks) < numticks:
#    1353             # Update the new tick label properties from the old.
# -> 1354             tick = self._get_tick(major=True)
#    1355             self.majorTicks.append(tick)
#    1356             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2052         else:
#    2053             tick_kw = self._minor_tick_kw
# -> 2054         return XTick(self.axes, 0, major=major, **tick_kw)
#    2055
#    2056     def set_label_position(self, position):
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     418
#     419     def __init__(self, *args, **kwargs):
# --> 420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
#     422         self.tick1line.set(
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     167             **grid_kw,
#     168         )
# --> 169         self.gridline.get_path()._interpolation_steps = \
#     170             GRIDLINE_INTERPOLATION_STEPS
#     171         self.label1 = mtext.Text(
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# ~\Documents\GitHub\virtual_environments\ML_project\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     670             y = self._y
#     671
# --> 672         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     673         self._x, self._y = self._xy.T  # views
#     674
#
# KeyboardInterrupt:

# %%
print(train_session.env.action_lookup)
# Out:
# [(-1, -1), (-1, 0), (-1, 1), (0, -1), (0, 0), (0, 1), (1, -1), (1, 0), (1, 1)]
