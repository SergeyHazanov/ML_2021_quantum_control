# %%
from train_network import Trainer
import matplotlib.pyplot as plt
import sys

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_session = Trainer(**{'simulation_type': 'two_qubits',
                           'n_epochs': 50,
                           'batch_size': 10000,
                           'games_per_epoch': 5,
                           'runtime': 2,
                           'dt': 0.05,
                           'load_net': False,
                           'net_name': 'two_qubit_net.pt',
                           'decay_rate': 0.96})
# Out:
# Two-qubits simulation initialized.

# %%
# %matplotlib inline

plt.style.use({'figure.facecolor': 'white'})
train_session.train()
# Out:
# 100%|██████████| 50/50 [00:55<00:00,  1.11s/it]

# %%
# %matplotlib qt

train_session.probe_learning()
# Out:
# Final fidelity is: 0.9993428433811277
# P_g = 0.0013138813829230806

# %%
# %matplotlib qt

plt.rcParams['animation.ffmpeg_path'] = r'C:/Users/rosengrp/Documents/GitHub\ML project\ML_2021_quantum_control/ffmpeg'
# anim = train_session.game_animation(fig_size=(12, 12), save=False, fps=60)
train_session.create_gif(fname='pi_pulse.mp4')
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (360, 360) to (368, 368) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
